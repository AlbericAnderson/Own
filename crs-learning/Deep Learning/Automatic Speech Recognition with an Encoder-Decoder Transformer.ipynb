# %% [markdown]
# # Automatic Speech Recognition with an Encoder-Decoder Transformer

# %% [markdown]
# # Schedule:
# - Checkpoint Submission (DUE 10 April 2026 @ 11:59PM EST)
# - Kaggle Submission (DUE 24 April 2026 @ 11:59PM EST | Slack Deadline is 1 May 2026 @ 11:59PM EST)
# - Code Submission (DUE 26 April 2026 @ 11:59PM EST OR Day-of Slack submission)

# %% [markdown]
# ## Requirement Acknowledgement
#
# Setting the flag below to **True** indicates that you have read, understood, and agree to comply with **all** of the following requirements:
#
# 1. **Slack Days Usage**
#    Slack days may be used **only** for the **P2 Final submission**, *not* for the checkpoint.
#    Specifically, slack days may be applied to submit **final P2 Kaggle scores** to the **Slack Kaggle Competition**, at the expense of your available slack days.
#
# 2. **Final Code Submission Deadline**
#    The final **Autolab code submission** is due **within 48 hours after** the Kaggle competition deadline,
#    or **on the same day** as your final Kaggle submission—whichever occurs first.
#
# 3. **Kaggle Username & Score Verification**
#    You must provide your **Kaggle username** below. We will use it to retrieve your official **PRIVATE leaderboard** score.
#    Minor score or output variance is acceptable; however, any discrepancies caused by **modifications to the required submission code**
#    (including the notebook’s final submission cell) will result in an **Academic Integrity Violation (AIV)**.
#
# 4. **Model Implementation Restrictions**
#    You are **not permitted** to use pre-trained or pre-loaded models (e.g., from Hugging Face or similar libraries).
#    You **may** implement models described in research papers or articles, but they **must** be implemented **from scratch**
#    using fundamental PyTorch components (e.g., `Linear`, `Conv2d`, etc.).
#
# 5. **Data Usage Restrictions**
#    The use of **any external data or datasets** is strictly prohibited at **any stage** of this assignment.
#
# 6. **Collaboration Policy**
#    You may collaborate with teammates to run experiments or ablations.
#    However, you must submit **your own code** and **your own results**.
#
# 7. **Academic Integrity**
#    Failure to comply with any of the above requirements will be treated as an **Academic Integrity Violation (AIV)**.
#
# 8. **Late Submissions**
#    Late submissions **must** be submitted through the **Slack Kaggle Competition** (see write-up for details).
#    Submissions made to the **regular Kaggle competition** after the original deadline will **not** be considered,
#    regardless of remaining slack days.

# %%
ACKNOWLEDGED = True #TODO: Only set Acknowledged to True if you have read the above acknowlegements and agree to ALL of them.

# %% [markdown]
# # Setup
# -  Follow the setup instructions based on your preferred environment!

# %% [markdown]
# ## Local

# %% [markdown]
# One of our key goals in designing this assignment is to allow you to complete most of the preliminary implementation work locally.
# We highly recommend that you **pass all tests locally** using the provided `hw4_data_subset` before moving to a GPU runtime.
# To do this, simply:
#
# ### Create a new conda environment
# ```bash
# # Be sure to deactivate any active environments first
# conda create -n hw4 python=3.12.4
# ```
#
# ### Activate the conda environment
# ```bash
# conda activate hw4
# ```
#
# ### Install the dependencies using the provided `requirements.txt`
# ```bash
# pip install --no-cache-dir --ignore-installed -r requirements.txt
# ```
#
# ### Ensure that your notebook is in the same working directory as the `Handout`
# This can be achieved by:
# 1. Physically moving the notebook into the handout directory.
# 2. Changing the notebook’s current working directory to the handout directory using the os.chdir() function.
#
# ### Open the notebook and select the newly created environment from the kernel selector.
#
# If everything was done correctly, You should see atleast the following files in your current working directory after running `!ls`:
# ```
# .
# ├── README.md
# ├── requirements.txt
# ├── hw4lib/
# ├── mytorch/
# ├── tests/
# └── hw4_data_subset/
# ```

# %% [markdown]
# ## Colab

# %% [markdown]
# ### Step 1: Get your handout
# - See writeup for recommended approaches.

# %%
# Example: My preferred approach
import os
# Settings -> Developer Settings -> Personal Access Tokens -> Token (classic)
os.environ['GITHUB_TOKEN'] = "your_github_token_here"

GITHUB_USERNAME = "your_github_username_here"
REPO_NAME       = "your_github_repo_name_here"
TOKEN = os.environ.get("GITHUB_TOKEN")
repo_url        = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git clone {repo_url}

# %%
# To pull latest changes (Must be in the repo dir, use pwd/ls to verify)
# !cd {REPO_NAME} && git pull

# %% [markdown]
# ### Step 2: Obtain Data
#
# - `NOTE`: This process will automatically download and unzip data for both `HW4P1` and `HW4P2`.

# %%
# !curl -L -o /content/s26-11785-hw4-data.zip https://www.kaggle.com/api/v1/datasets/download/cmu11785/s26-11785-hw4-data
# !unzip -q -o /content/s26-11785-hw4-data.zip -d /content/hw4_data
# !rm -rf /content/s26-11785-hw4-data.zip
# !du -h --max-depth=2 /content/hw4_data

# %% [markdown]
# ### Step 3: Set up Kaggle API Authentication

# %% [markdown]
# Join the HW4P2 kaggle competition (https://www.kaggle.com/t/9a00ec2986e64408b581250f8a401880)

# %%
import os
os.environ['KAGGLE_USERNAME'] = "<your-username>" # TODO: Verify in Settings
os.environ['KAGGLE_API_TOKEN'] = "<your-key>" # TODO: Add Access Token

# Verify
import kaggle
api = kaggle.api  # Already authenticated on import

# Verify authentication works
api.competitions_list_cli()
api.competition_download_files('11785-hw-4-p-2-asr-with-transformer-spring-2026')  # TODO: Replace with actual competition name

# %% [markdown]
# ### Step 4: Install Dependencies
# - `NOTE`: Your runtime will be restarted to ensure all dependencies are updated.
# - `NOTE`: You will see a runtime crashed message, this was intentionally done. Simply move on to the next cell.

# %%
# !pwd
# %cd /content/

# %%
# %pip install --no-deps -r IDL-HW4/requirements.txt
import os
os.kill(os.getpid(), 9) # NOTE: This will restart the your colab Python runtime (required)!

# %%
# !pip install transformers -U

# %% [markdown]
# ### Step 5: Move to Handout Directory
# You must be within the handout directory for the library imports to work!
#
# - `NOTE`: You may have to repeat running this command anytime you restart your runtime.
# - `NOTE`: You can do a `pwd` to check if you are in the right directory.
# - `NOTE`: The way it is setup currently, Your data directory should be one level up from your project directory. Keep this in mind when you are setting your `root` in the config file.
#
# If everything was done correctly, You should see atleast the following files in your current working directory after running `!ls`:
# ```
# .
# ├── README.md
# ├── requirements.txt
# ├── hw4lib/
# ├── mytorch/
# ├── tests/
# └── hw4_data_subset/
#
# ```

# %%
import os
os.chdir('IDL-HW4')
# !ls

# %% [markdown]
# ## PSC

# %% [markdown]
# ### 1️⃣ **Step 1 Setting Up Your Environment on Bridges2**
#
# ❗️⚠️ For this homework, we are **providing a shared Conda environment** for the entire class. Therefore, PSC users **do not need to manually install any packages**.
#
# ❗️⚠️ For this homework, you need to **download the dataset to the node `$LOCAL`** to avoid I/O bottlenecks from the shared filesystem. This means that each time you run on a new node, you need to download the dataset again. However, as long as you stay on the same node, you do not need to re-download the dataset. Please refer to **Step 3** for the detailed procedure.
#
# Follow these steps to set up the environment and start a Jupyter notebook on Bridges2:
#
# - To run your notebook more efficiently on PSC, we need to use a **Jupyter Server** hosted on a compute node.
#
# - You can use your prefered way of connecting to the Jupyter Server.  **The recommended way is to connect in VSCode.**
# Follow the instructions below.

# %% [markdown]
# **The recommended way of connecting is:**
#
# #### **Connect in VSCode**
# SSH into Bridges2 and navigate to your **Jet directory** (`Jet/home/<your_psc_username>`). Upload your notebook there, and then connect to the Jupyter Server from that directory.

# %% [markdown]
# #### **1. SSH into Bridges2**
# 1）Open VS Code and click on the `Extensions` icon in the left sidebar. Make sure the "**Remote - SSH**" extension is installed.
#
# 2）Open the command palette (**Shift+Command+P** on Mac, **Ctrl+Shift+P** on Windows). A search box will appear at the top center. Choose `"Remote-SSH: Add New SSH Host"`, then enter:
#
# ```bash
# ssh <your_username>@bridges2.psc.edu #change <your_username> to your username
# ```
#
# Next, choose `"/Users/<your_username>/.ssh/config"` as the config file. A dialog will appear in the bottom right saying "Host Added". Click `"Connect"`, and then enter your password.
#
# (Note: After adding the host once, you can later use `"Remote-SSH: Connect to Host"` and select "bridges2.psc.edu" from the list.)
#
# 3）Once connected, click `"Explorer"` in the left sidebar > "Open Folder", and navigate to your home directory under the project grant:
# ```bash
# /jet/home/<your_username>  #change <your_username> to your username
# ```
#
# 4）You can now drag your notebook files directly into the right-hand pane (your remote home directory), or upload them using `scp` into your folder.

# %% [markdown]
# > ❗️⚠️ The following steps should be executed in the **VSCode integrated terminal**.

# %% [markdown]
# #### **2. Navigate to Your Directory**
# Make sure to use this `/jet/home/<your_username>` as your working directory, since all subsequent operations (up to submission) are based on this path.
# ```bash
# cd /jet/home/<your_username>  #change <your_username> to your username
# ```

# %% [markdown]
# #### **3. Request a Compute Node**
# ```bash
# interact -p GPU-shared --gres=gpu:v100-32:1 -t 8:00:00 -A cis250019p
# ```

# %% [markdown]
# #### **4. Load the Anaconda Module**
# ```bash
# module load anaconda3
# ```

# %% [markdown]
# #### **5. Activate the provided HW4 Environment**
#
# ```bash
# conda deactivate # First, deactivate any existing Conda environment
# conda activate /ocean/projects/cis250019p/mzhang23/TA/envs/IDLS26 && export PYTHONNOUSERSITE=1

# %% [markdown]
# #### **6. Start Jupyter Notebook**
# Launch Jupyter Notebook:
# ```bash
# jupyter notebook --no-browser --ip=0.0.0.0
# ```
#
# Go to **Kernel** → **Select Another Kernel** → **Existing Jupyter Server**
#    Enter the URL of the Jupyter Server:```http://{hostname}:{port}/tree?token={token}```
#
#    *(Usually, this URL appears in the terminal output after you run `jupyter notebook --no-browser --ip=0.0.0.0`, in a line like:  “Jupyter Server is running at: http://...”)*
#
#    - eg: `http://v011.ib.bridges2.psc.edu:8888/tree?token=e4b302434e68990f28bc2b4ae8d216eb87eecb7090526249`
#
# > **Note**: Replace `{hostname}`, `{port}` and `{token}` with your actual values from the Jupyter output.

# %% [markdown]
# After launching the Jupyter notebook, you can run the cells directly inside the notebook — no need to use the terminal for the remaining steps.

# %% [markdown]
# ### 2️⃣ Step 2: Get Repo

# %%
#Make sure you are in your directory
# !pwd #should be /jet/home/<your_username>, if not, uncomment the following line and replace with your actual username:
# %cd /ocean/projects/cis260061p/awolosso/IDL/HW4
# !pwd
#TODO: replace the "<your_username>" to yours
# Out:
# /ocean/projects/cis260061p/awolosso/IDL/HW4
# /ocean/projects/cis260061p/awolosso/IDL/HW4
# /ocean/projects/cis260061p/awolosso/IDL/HW4

# %%
# Example: My preferred approach
import os
# Settings -> Developer Settings -> Personal Access Tokens -> Token (classic)
os.environ['GITHUB_TOKEN'] = "git_key"

GITHUB_USERNAME = "AlbericAnderson"
REPO_NAME       = "IDL26-HW4"
TOKEN = os.environ.get("GITHUB_TOKEN")
repo_url        = f"https://{TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
#!git clone {repo_url}

# %%
# To pull latest changes (Must be in the repo dir, use pwd/ls to verify)
# !cd {REPO_NAME} && git pull
# Out:
# Already up to date.

# %% [markdown]
# #### **Move to Project Directory**
# - `NOTE`: You may have to repeat this on anytime you restart your runtime. You can do a `pwd` or `ls` to check if you are in the right directory.

# %%
import os
os.chdir('/ocean/projects/cis260061p/awolosso/IDL/HW4/IDL26-HW4')
# !ls
# Out:
#  config.yaml	   hw4lib				       README.md
#  expts		   HW4P1_nb.ipynb			       requirements.txt
#  handin		  'HW4P2_Student_Starter_Notebook (1).ipynb'   results.csv
#  handin.tar	   lm_config.yaml			       tests
#  hw4_data_subset   mytorch				       wandb

# %% [markdown]
# ### 3️⃣ **Step 3: Set up Kaggle API Authentication**

# %% [markdown]
# Join the HW4P2 kaggle competition (https://www.kaggle.com/t/9a00ec2986e64408b581250f8a401880)

# %%
import os
import pprint
os.environ['KAGGLE_USERNAME'] = "andersonawolossou" # TODO: Verify in Settings
os.environ['KAGGLE_API_TOKEN'] = "Kaggle_key" # TODO: Add Access Token (must be the new token starting with "KGAT_")

# Verify
import kaggle
api = kaggle.api  # Already authenticated on import
api.competitions_list_cli()
# Out:
# ref                                                                              deadline             category         reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  --------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/passenger-screening-algorithm-challenge      2017-12-15 23:59:00  Featured  1,500,000 Usd        518           False
# https://www.kaggle.com/competitions/zillow-prize-1                               2018-01-10 15:59:00  Featured  1,200,000 Usd       3770           False
# https://www.kaggle.com/competitions/data-science-bowl-2017                       2017-04-12 23:59:00  Featured  1,000,000 Usd       1972           False
# https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection             2023-06-14 23:59:00  Featured  1,000,000 Usd       1249           False
# https://www.kaggle.com/competitions/arc-prize-2026-arc-agi-3                     2026-11-02 23:59:00  Featured    850,000 Usd        633           False
# https://www.kaggle.com/competitions/arc-prize-2026-arc-agi-2                     2026-11-02 23:59:00  Featured    700,000 Usd        476           False
# https://www.kaggle.com/competitions/gemini-3                                     2025-12-12 23:59:00  Featured    500,000 Usd       4095           False
# https://www.kaggle.com/competitions/openai-gpt-oss-20b-red-teaming               2025-08-26 23:59:00  Featured    500,000 Usd        604           False
# https://www.kaggle.com/competitions/openai-to-z-challenge                        2025-06-29 23:59:00  Featured    500,000 Usd        225           False
# https://www.kaggle.com/competitions/arc-prize-2026-paper-track                   2026-11-09 23:59:00  Featured    450,000 Usd         30           False
# https://www.kaggle.com/competitions/llm-prompt-recovery                          2024-04-16 23:59:00  Featured    200,000 Usd       2175           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection         2026-02-27 23:59:00  Research    200,000 Usd       1391           False
# https://www.kaggle.com/competitions/asl-fingerspelling                           2023-08-24 23:59:00  Research    200,000 Usd       1314           False
# https://www.kaggle.com/competitions/second-annual-data-science-bowl              2016-03-14 23:59:00  Featured    200,000 Usd        192           False
# https://www.kaggle.com/competitions/kaggle-measuring-agi                         2026-04-16 23:59:00  Featured    200,000 Usd       1071           False
# https://www.kaggle.com/competitions/gemma-4-good-hackathon                       2026-05-18 23:59:00  Featured    200,000 Usd        127           False
# https://www.kaggle.com/competitions/datasciencebowl                              2015-03-16 23:59:00  Featured    175,000 Usd       1049           False
# https://www.kaggle.com/competitions/data-science-bowl-2019                       2020-01-22 23:59:00  Featured    160,000 Usd       3493           False
# https://www.kaggle.com/competitions/feedback-prize-2021                          2022-03-15 23:59:00  Featured    160,000 Usd       2058           False
# https://www.kaggle.com/competitions/the-nature-conservancy-fisheries-monitoring  2017-04-12 23:59:00  Featured    150,000 Usd       2293           False

# %% [markdown]
# ### 4️⃣ **Step 4: Get Data**
#
# ❗️⚠️ In this homework, you need to download the dataset to the **GPU node’s local storage (`$LOCAL`)** instead of using the shared /ocean directory, in order to avoid I/O bottlenecks. Using the shared filesystem may slow down training drastically and can take hours per epoch.
#
# Note that **the local storage on a compute node is temporary and will be cleared** when your node time limit is reached or when you move to a different node. Therefore, **every time you run on a new node, you need to re-run the dataset download step**. However, as long as you stay on the same node, you do NOT need to download the dataset again.

# %%
# !mkdir -p $LOCAL/dataset
api.dataset_download_files(
    "cmu11785/s26-11785-hw4-data",
    path=f"{os.environ['LOCAL']}/dataset",
    unzip=True
)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/cmu11785/s26-11785-hw4-data

# %%
import os
data_path = "/local/dataset/hw4p2_data" # this is the path of the dataset on your node
print("Files in shared hw4p2 dataset:", os.listdir(data_path))
# Out:
# Files in shared hw4p2 dataset: ['char_set.txt', 'dev-clean', 'test-clean', 'train-clean-100']

# %%
# !apt-get install tree
# !tree -L 2 /local/dataset/hw4p2_data
# Out:
# /bin/bash: apt-get: command not found
# /local/dataset/hw4p2_data
# ├── char_set.txt
# ├── dev-clean
# │   ├── fbank
# │   └── text
# ├── test-clean
# │   └── fbank
# └── train-clean-100
#     ├── fbank
#     └── text
#
# 8 directories, 1 file

# %% [markdown]
# # Imports
# - If your setup was done correctly, you should be able to run the following cell without any issues.

# %%
from hw4lib.data import (
    H4Tokenizer,
    ASRDataset,
    LMDataset,
    verify_dataloader
)
from hw4lib.model import (
    CausalMask,
    PadMask,
    PositionalEncoding,
    DecoderOnlyTransformer,
    EncoderDecoderTransformer
)
from hw4lib.utils import (
    create_scheduler,
    create_optimizer,
    plot_lr_schedule
)
from hw4lib.trainers import (
    LMTrainer,
    ASRTrainer,
    ProgressiveTrainer
)
from torch.utils.data import DataLoader
import yaml
import gc
import torch
from torchinfo import summary
import os
import json
import wandb
import pandas as pd
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Implementations
# - `NOTE`: All of these implementations have detailed specification, implementation details, and hints in their respective source files. Make sure to read all of them in their entirety to understand the implementation details!

# %% [markdown]
# ## Dataset Implementation
# - Implement the `ASRDataset` class in `hw4lib/data/asr_dataset.py`.
# - You will have to implement parts of `__init__` and completely implement the `__len__`, `__getitem__` and `collate_fn` methods.
# - Run the cell below to check your implementation.

# %%
# !python -m tests.test_dataset_asr
# Out:
# Loading data for train-clean-100 partition...
# 100%|███████████████████████████████████████████| 28/28 [00:02<00:00, 13.38it/s]
# Loading data for test-clean partition...
# 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 753.56it/s]
#
# ================================================================================
# Running tests for category: ASRDataset Train
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test a Train instance of ASRDataset class
# Testing __init__ method ...
# Test Passed: Dataset length matches FBANK files.
# Test Passed: Dataset length matches TRANSCRIPT files.
# Test Passed: Order alignment between FBANK files and TRANSCRIPT files is correct.
# Test Passed: Alignment between features and transcripts is correct.
# Test Passed: All features have the correct number of dimensions (num_feats).
# Test Passed: All transcripts are decoded correctly after removing SOS and EOS tokens.
# Testing __getitem__ method ...
# Test Passed: All samples have correct feature dimensions and transcript alignment.
# Testing collate_fn method ...
# Test Passed: Feature batch has correct dimensions (3D tensor).
# Test Passed: All sequences are padded to the same length.
# Test Passed: All transcripts are padded to the same length.
# Test Passed: Padding values are correct.
# [01/01]    PASSED:   Test a Train instance of ASRDataset class
#
#
# ================================================================================
# Running tests for category: ASRDataset Test
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test a Test instance of ASRDataset class
# Testing __init__ method ...
# Test Passed: Dataset length matches FBANK files.
# Test Passed: All features have the correct number of dimensions (num_feats).
# Testing __getitem__ method ...
# Test Passed: Transcripts are None for 'test-clean' at index 0.
# Test Passed: Transcripts are None for 'test-clean' at index 1.
# Test Passed: All samples have correct feature dimensions and transcript alignment.
# Testing collate_fn method ...
# Test Passed: Feature batch has correct dimensions (3D tensor).
# Test Passed: All sequences are padded to the same length.
# Test Passed: Transcripts and lengths are correctly set to None for 'test-clean'.
# [01/01]    PASSED:   Test a Test instance of ASRDataset class
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    ASRDataset Train
# Results:     1/1 tests passed (100.0%)
# Category:    ASRDataset Test
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ## Model Implementations
#
# Overview:
#
# - Implement the `CrossAttentionLayer` class in `hw4lib/model/sublayers.py`.
# - Implement the `CrossAttentionDecoderLayer` class in `hw4lib/model/decoder_layers.py`.
# - Implement the `SelfAttentionEncoderLayer` class in `hw4lib/model/encoder_layers.py`. This will be mostly a copy-paste of the `SelfAttentionDecoderLayer` class in `hw4lib/model/decoder_layers.py` with one minor diffrence: it can attend to all positions in the input sequence.
# - Implement the `EncoderDecoderTransformer` class in `hw4lib/model/transformers.py`.

# %% [markdown]
# ### Transformer Sublayers
# - Now, Implement the `CrossAttentionLayer` class in `hw4lib/model/sublayers.py`.
# - `NOTE`: You should have already implemented the `SelfAttentionLayer`, and `FeedForwardLayer` classes in `hw4lib/model/sublayers.py`.
# - Run the cell below to check your implementation.

# %%
# !python -m tests.test_sublayer_crossattention
# Out:
# ================================================================================
# Running tests for category: CrossAttentionLayer
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test the cross-attention sublayer
# Testing initialization ...
# Test Passed: All layers exist and are instantiated correctly
# Testing forward shapes ...
# Test Passed: Forward pass returns the correct shapes
# Testing padding mask behaviour ...
# Test Passed: Padding mask is applied correctly
# Testing cross-attention behaviour ...
# Test Passed: Cross-attention behavior is correct
# Testing residual connection ...
# Test Passed: Residual connection is applied correctly
# [01/01]    PASSED:   Test the cross-attention sublayer
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    CrossAttentionLayer
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ### Transformer Cross-Attention Decoder Layer
# - Implement the `CrossAttentionDecoderLayer` class in `hw4lib/model/decoder_layers.py`.
# - Then run the cell below to check your implementation.

# %%
# !python -m tests.test_decoderlayer_crossattention
# Out:
# ================================================================================
# Running tests for category: CrossAttentionDecoderLayer
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test the cross-attention decoder layer
# Testing initialization ...
# Test Passed: All sublayers exist and are initialized correctly
# Testing forward shapes ...
# Test Passed: Forward shapes are as expected
# Testing sublayer integration ...
# Test Passed: Sublayers interact correctly
# Testing cross-attention behavior ...
# Test Passed: Cross-attention behaves correctly
# [01/01]    PASSED:   Test the cross-attention decoder layer
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    CrossAttentionDecoderLayer
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ### Transformer Self-Attention Encoder Layer
# - Implement the `SelfAttentionEncoderLayer` class in `hw4lib/model/encoder_layers.py`.
# - Then run the cell below to check your implementation.

# %%
# !python -m tests.test_encoderlayer_selfattention
# Out:
# ================================================================================
# Running tests for category: SelfAttentionEncoderLayer
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test the self-attention encoder layer
# Testing initialization ...
# Test Passed: All sublayers exist and are initialized correctly
# Testing forward shapes ...
# Test Passed: Forward shapes are as expected
# Testing sublayer interaction ...
# Test Passed: Sublayers interact correctly
# Testing bidirectional attention ...
# Test Passed: Bidirectional attention is working correctly
# [01/01]    PASSED:   Test the self-attention encoder layer
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    SelfAttentionEncoderLayer
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ### Encoder-Decoder Transformer
#
# - Implement the  `EncoderDecoderTransformer` class in `hw4lib/model/transformers.py`.
# - Then run the cell below to check your implementation.

# %%
# !python -m tests.test_transformer_encoder_decoder
# Out:
# ================================================================================
# Running tests for category: EncoderDecoderTransformer
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test the encoder-decoder transformer
# Testing initialization...
# Test Passed: All components initialized correctly
# Testing encode method...
# Test Passed: Encode method works correctly
# Testing decode method...
# Test Passed: Decode method works correctly
# Testing forward pass...
# Test Passed: Forward pass works correctly
# Testing encoder-decoder integration...
# Test Passed: Encoder-decoder integration works correctly
# Testing CTC integration...
# Test Passed: CTC integration works correctly
# Testing forward propagation order...
# Test Passed: Forward propagation order is correct
# [01/01]    PASSED:   Test the encoder-decoder transformer
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    EncoderDecoderTransformer
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ## Decoding Implementation
# - We highly recommend you to implement the `generate_beam` method of the `SequenceGenerator` class in `hw4lib/decoding/sequence_generator.py`.
# - Then run the cell below to check your implementation.
# - `NOTE`: This is an optional but highly recommended task for `HW4P2` to ease the journey to high cutoffs!

# %%
# !python -m tests.test_decoding --mode beam
# Out:
# ================================================================================
# Running tests for category: Decoding
# --------------------------------------------------------------------------------
#
# [01/01]    Running:  Test beam decoding
# Testing Single Batch Beam Search ...
# Beam 0  : generated: HELLO WORLD  | expected: HELLO WORLD
# Beam 1  : generated: YELLOW WORLD | expected: YELLOW WORLD
# Beam 2  : generated: MELLOW WORLD | expected: MELLOW WORLD
# Testing Multi Batch Beam Search ...
# Batch 0  : Beam 0  : generated: HELLO WORLD  | expected: HELLO WORLD
# Batch 0  : Beam 1  : generated: YELLOW WORLD | expected: YELLOW WORLD
# Batch 0  : Beam 2  : generated: MELLOW WORLD | expected: MELLOW WORLD
# Batch 1  : Beam 0  : generated: GOOD BYE     | expected: GOOD BYE
# Batch 1  : Beam 1  : generated: GREAT DAY    | expected: GREAT DAY
# Batch 1  : Beam 2  : generated: GUD NIGHT    | expected: GUD NIGHT
# [01/01]    PASSED:   Test beam decoding
#
#
# ================================================================================
#                                   Test Summary
# ================================================================================
# Category:    Decoding
# Results:     1/1 tests passed (100.0%)

# %% [markdown]
# ## Trainer Implementation
# You will have to do some minor in-filling for the `ASRTrainer` class in `hw4lib/trainers/asr_trainer.py` before you can use it.
# - Fill in the `TODO`s in the `__init__`.
# - Fill in the `TODO`s in the `_train_epoch`.
# - Fill in the `TODO`s in the `recognize` method.
# - Fill in the `TODO`s in the `_validate_epoch`.
# - Fill in the `TODO`s in the `train` method.
# - Fill in the `TODO`s in the `evaluate` method.
#
# `WARNING`: There are no test's for this. Implement carefully!

# %% [markdown]
# # Experiments
# From this point onwards you may want to switch to a `GPU` runtime.
# - `OBJECTIVE`: Optimize your model for `CER` on the test set.

# %% [markdown]
# ## Config
# - You can use the `config.yaml` file to set your config for your ablation study.
#
# ---
# ### Notes:
#
# - Set `tokenization: token_type:` to specify your desired tokenization strategy
# - You will need to set the root path to your `hw4p2_data` folder in `data: root:`. This will depend on your setup. For eg.
#   - `Colab:`: `"/content/hw4_data/hw4p2_data"`
#   - `PSC`: `"/local/dataset/hw4p2_data"`
# - There's extra configurations in the `optimizer` section which will only be relevant if you decide to use the `create_optimizer` function we've provided in `hw4lib/utils/create_optimizer.py`.
# - `BE CAREFUL` while setting numeric values. Eg. `1e-4` will get serialized to a `str` while `1.0e-4` gets serialized to float.

# %%
# %%writefile config.yaml
#
# Name                      : "Anderson Awolossou"
#
# ###### Tokenization ------------------------------------------------------------
# tokenization:
#   token_type                : "5k"       # [char, 1k, 5k, 10k]
#   token_map :
#       'char': 'hw4lib/data/tokenizer_jsons/tokenizer_char.json'
#       '1k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_1000.json'
#       '5k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_5000.json'
#       '10k' : 'hw4lib/data/tokenizer_jsons/tokenizer_10000.json'
#
# ###### Dataset -----------------------------------------------------------------
# data:
#   root                 : "/local/dataset/hw4p2_data"  # TODO: Set the root path of your data
#   train_partition      : "train-clean-100"  # paired text-speech for ASR pre-training
#   val_partition        : "dev-clean"        # paired text-speech for ASR pre-training
#   test_partition       : "test-clean"       # paired text-speech for ASR pre-training
#   subset               : 1.0                # Load a subset of the data (for debugging, testing, etc
#   batch_size           : 16           #
#   NUM_WORKERS          : 2            # Set to 0 for CPU
#   norm                 : 'global_mvn' # ['global_mvn', 'cepstral', 'none']
#   num_feats            : 80
#
#   ###### SpecAugment ---------------------------------------------------------------
#   specaug                   : False  # Set to True if you want to use SpecAugment
#   specaug_conf:
#     apply_freq_mask         : True
#     freq_mask_width_range   : 5
#     num_freq_mask           : 2
#     apply_time_mask         : True
#     time_mask_width_range   : 40
#     num_time_mask           : 2
#
# ###### Network Specs -------------------------------------------------------------
#
# model: # Encoder-Decoder Transformer (HW4P2)
#   # Speech embedding parameters
#   input_dim: 80              # Speech feature dimension
#   time_reduction: 8          # Time dimension downsampling factor
#   reduction_method: 'lstm'   # The source_embedding reduction method ['lstm', 'conv', 'both']
#
#   # Architecture parameters
#   d_model: 324           # Model dimension
#   num_encoder_layers: 6  # Number of encoder layers
#   num_decoder_layers: 6  # Number of decoder layers
#   num_encoder_heads: 4   # Number of encoder attention heads
#   num_decoder_heads: 4   # Number of decoder attention heads
#   d_ff_encoder: 2048     # Feed-forward dimension for encoder
#   d_ff_decoder: 2048     # Feed-forward dimension for decoder
#   skip_encoder_pe: False # Whether to skip positional encoding for encoder
#   skip_decoder_pe: False # Whether to skip positional encoding for decoder
#
#   # Common parameters
#   dropout: 0.2          # Dropout rate
#   layer_drop_rate: 0.2  # Layer dropout rate
#   weight_tying: False   # Whether to use weight tying
#
# ###### Common Training Parameters ------------------------------------------------
# training:
#   use_wandb                   : True   # Toggle wandb logging
#   wandb_run_id                : "none" # "none" or "run_id"
#   resume                      : True   # Resume an existing run (run_id != 'none')
#   gradient_accumulation_steps : 1 # 1
#   wandb_project               : "IDL-HW4-P2" # wandb project to log to
#
# ##### Evaluation
# evaluation:
#   method: "greedy" #
#
#
# ###### Loss ----------------------------------------------------------------------
# loss: # Just good ol' CrossEntropy
#   label_smoothing: 0.01
#   ctc_weight: 0.2
#
# ###### Optimizer -----------------------------------------------------------------
# optimizer:
#   name: "adamw" # Options: sgd, adam, adamw
#   lr: 0.001 #0.0004    # Base learning rate
#
#   # Common parameters
#   weight_decay: 0.000001
#
#   # Parameter groups
#   # You can add more param groups as you want and set their learning rates and patterns
#   param_groups:
#     - name: self_attn
#       patterns: []  # Will match all parameters containing "ffn" and set their learning rate to 0.0002
#       lr: 0.0005 #0.0002    # LR for self_attn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#     - name: ffn
#       patterns: [] # Will match all parameters containing "ffn" and set their learning rate to 0.0002
#       lr: 0.0005 #0.0002   # LR for ffn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#   # Layer-wise learning rates
#   layer_decay:
#     enabled: False
#     decay_rate: 0.75
#
#   # SGD specific parameters
#   sgd:
#     momentum: 0.9
#     nesterov: True
#     dampening: 0
#
#   # Adam specific parameters
#   adam:
#     betas: [0.9, 0.99]
#     eps: 1.0e-9
#     amsgrad: False
#
#   # AdamW specific parameters
#   adamw:
#     betas: [0.9, 0.99]
#     eps: 1.0e-9
#     amsgrad: False
#
# ###### Scheduler -----------------------------------------------------------------
# scheduler:
#   name: "cosine"  # Options: reduce_lr, cosine, cosine_warm
#
#   # ReduceLROnPlateau specific parameters
#   reduce_lr:
#     mode: "min"  # Options: min, max
#     factor: 0.1  # Factor to reduce learning rate by
#     patience: 10  # Number of epochs with no improvement after which LR will be reduced
#     threshold: 0.0001  # Threshold for measuring the new optimum
#     threshold_mode: "rel"  # Options: rel, abs
#     cooldown: 0  # Number of epochs to wait before resuming normal operation
#     min_lr: 0.0006 #0.0000001  # Minimum learning rate
#     eps: 1e-8  # Minimal decay applied to lr
#
#   # CosineAnnealingLR specific parameters
#   cosine:
#     T_max: 15  # Maximum number of iterations
#     eta_min: 0.0001 #0.0000001  # Minimum learning rate
#     last_epoch: -1
#
#   # CosineAnnealingWarmRestarts specific parameters
#   cosine_warm:
#     T_0: 15    # Number of iterations for the first restart
#     T_mult: 2 # Factor increasing T_i after each restart
#     eta_min: 0.0001 #0.0000001  # Minimum learning rate
#     last_epoch: -1
#
#   # Warmup parameters (can be used with any scheduler)
#   warmup:
#     enabled: True
#     type: "linear"  # Options: linear, exponential
#     epochs: 5
#     start_factor: 0.1
#     end_factor: 1.0
# Out:
# Overwriting config.yaml

# %%
with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %%
# %%writefile lm_config.yaml
#
# Name                      : "Anderson Awolossou"
#
# ###### Tokenization ------------------------------------------------------------
# tokenization:
#   token_type                : "5k"       # [char, 1k, 5k, 10k]
#   token_map :
#       'char': 'hw4lib/data/tokenizer_jsons/tokenizer_char.json'
#       '1k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_1000.json'
#       '5k'  : 'hw4lib/data/tokenizer_jsons/tokenizer_5000.json'
#       '10k' : 'hw4lib/data/tokenizer_jsons/tokenizer_10000.json'
#
# ###### Dataset -----------------------------------------------------------------
# data:                    # Currently setup for Colab assuming out setup
#   root                 : "/local/hw4_data/hw4p1_data"  # TODO: Set the root path of your data
#   train_partition      : "train"  # train
#   val_partition        : "val"    # val
#   test_partition       : "test"   # test
#   subset               : 1.0      # Load a subset of the data (for debugging, testing, etc
#   batch_size           : 16      #
#   NUM_WORKERS          : 2        # Set to 0 for CPU
#
# ###### Network Specs -------------------------------------------------------------
# model: # Decoder-Only Language Model (HW4P1)
#   d_model                   : 256
#   d_ff                      : 1024
#   num_layers                : 2
#   num_heads                 : 2
#   dropout                   : 0.0
#   layer_drop_rate           : 0.0
#   weight_tying              : False
#
# ###### Common Training Parameters ------------------------------------------------
# training:
#   use_wandb                   : True   # Toggle wandb logging
#   wandb_run_id                : "none" # "none" or "run_id"
#   resume                      : False  # Resume an existing run (run_id != 'none')
#   epochs                      : 30
#   gradient_accumulation_steps : 1
#   wandb_project               : "IDL26-hw4-p1" # wandb project to log to
#
# ###### Loss ----------------------------------------------------------------------
# loss: # Just good ol' CrossEntropy
#   label_smoothing: 0.0
#
# ###### Optimizer -----------------------------------------------------------------
# optimizer:
#   name: "adam" # Options: sgd, adam, adamw
#   lr: 5.0e-4   # Base learning rate
#
#   # Common parameters
#   weight_decay: 0.0001
#
#   # Parameter groups
#   param_groups:
#     - name: self_attn
#       patterns: []  # Will match all parameters containing keywords set their learning rate to 0.0001
#       lr: 0.0001    # LR for self_attn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#     - name: ffn
#       patterns: [] # Will match all parameters containing "ffn" and set their learning rate to 0.0001
#       lr: 0.0001   # LR for ffn
#       layer_decay:
#         enabled: False
#         decay_rate: 0.8
#
#   # Layer-wise learning rates
#   layer_decay:
#     enabled: False
#     decay_rate: 0.75
#
#   # SGD specific parameters
#   sgd:
#     momentum: 0.9
#     nesterov: True
#     dampening: 0
#
#   # Adam specific parameters
#   adam:
#     betas: [0.9, 0.999]
#     eps: 1.0e-8
#     amsgrad: False
#
#   # AdamW specific parameters
#   adamw:
#     betas: [0.9, 0.999]
#     eps: 1.0e-8
#     amsgrad: False
#
# ###### Scheduler -----------------------------------------------------------------
# scheduler:
#   name: "cosine"  # Options: reduce_lr, cosine, cosine_warm
#
#   # ReduceLROnPlateau specific parameters
#   reduce_lr:
#     mode: "min"  # Options: min, max
#     factor: 0.1  # Factor to reduce learning rate by
#     patience: 10  # Number of epochs with no improvement after which LR will be reduced
#     threshold: 0.0001  # Threshold for measuring the new optimum
#     threshold_mode: "rel"  # Options: rel, abs
#     cooldown: 0  # Number of epochs to wait before resuming normal operation
#     min_lr: 0.0000001  # Minimum learning rate
#     eps: 1.0e-8  # Minimal decay applied to lr
#
#   # CosineAnnealingLR specific parameters
#   cosine:
#     T_max: 15  # Maximum number of iterations # 80
#     eta_min: 1.0e-8  # Minimum learning rate # 1.0e-6
#     last_epoch: -1
#
#   # CosineAnnealingWarmRestarts specific parameters
#   cosine_warm:
#     T_0: 4  # Number of iterations for the first restart
#     T_mult: 4  # Factor increasing T_i after each restart
#     eta_min: 0.0000001  # Minimum learning rate
#     last_epoch: -1
#
#   # Warmup parameters (can be used with any scheduler)
#   warmup:
#     enabled: True
#     type: "exponential"  # Options: linear, exponential
#     epochs: 5
#     start_factor: 0.1
#     end_factor: 1.0
# Out:
# Overwriting lm_config.yaml

# %%
with open('lm_config.yaml', 'r') as file:
    lm_config = yaml.safe_load(file)

# %% [markdown]
# ## Tokenizer

# %%
Tokenizer = H4Tokenizer(
    token_map  = config['tokenization']['token_map'],
    token_type = config['tokenization']['token_type']
)
# Out:
# ================================================================================
#                           Tokenizer Configuration (5k)
# --------------------------------------------------------------------------------
# Vocabulary size:     5000
#
# Special Tokens:
# PAD:              0
# UNK:              1
# MASK:             2
# SOS:              3
# EOS:              4
# BLANK:            5
#
# Validation Example:
# --------------------------------------------------------------------------------
# Input text:  [SOS]HI DEEP LEARNERS[EOS]
# Tokens:      ['[SOS]', 'H', 'I', 'ĠDEEP', 'ĠLEARN', 'ERS', '[EOS]']
# Token IDs:   [3, 14, 15, 1169, 2545, 214, 4]
# Decoded:     [SOS]HI DEEP LEARNERS[EOS]
# ================================================================================

# %% [markdown]
# ## Datasets

# %%
train_dataset = ASRDataset(
    partition=config['data']['train_partition'],
    config=config['data'],
    tokenizer=Tokenizer,
    isTrainPartition=True,
    global_stats=None  # Will compute stats from training data
)

# TODO: Get the computed global stats from training set
global_stats = None
if config['data']['norm'] == 'global_mvn':
    global_stats = (train_dataset.global_mean, train_dataset.global_std)
    print(f"Global stats computed from training set.")

val_dataset = ASRDataset(
    partition=config['data']['val_partition'],
    config=config['data'],
    tokenizer=Tokenizer,
    isTrainPartition=False,
    global_stats=global_stats
)

test_dataset = ASRDataset(
    partition=config['data']['test_partition'],
    config=config['data'],
    tokenizer=Tokenizer,
    isTrainPartition=False,
    global_stats=global_stats
)

gc.collect()
# Out:
# Loading data for train-clean-100 partition...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28539/28539 [00:23<00:00, 1210.66it/s]
# Global stats computed from training set.
# Loading data for dev-clean partition...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2703/2703 [00:01<00:00, 2357.91it/s]
# Loading data for test-clean partition...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2620/2620 [00:00<00:00, 4269.13it/s]
# 887

# %% [markdown]
# ## Dataloaders

# %%
train_loader    = DataLoader(
    dataset     = train_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = True,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = train_dataset.collate_fn
)

val_loader      = DataLoader(
    dataset     = val_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = False,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = val_dataset.collate_fn
)

test_loader     = DataLoader(
    dataset     = test_dataset,
    batch_size  = config['data']['batch_size'],
    shuffle     = False,
    num_workers = config['data']['NUM_WORKERS'] if device == 'cuda' else 0,
    pin_memory  = True,
    collate_fn  = test_dataset.collate_fn
)

gc.collect()
# Out:
# 0

# %% [markdown]
# ### Dataloader Verification

# %%
verify_dataloader(train_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : train-clean-100
# --------------------------------------------------
# Number of Batches        : 1784
# Batch Size               : 16
# --------------------------------------------------
# Checking shapes of the data...
#
# Feature Shape            : [16, 1999, 80]
# Shifted Transcript Shape : [16, 59]
# Golden Transcript Shape  : [16, 59]
# Feature Lengths Shape    : [16]
# Transcript Lengths Shape : [16]
# --------------------------------------------------
# Max Feature Length       : 3066
# Max Transcript Length    : 100
# Avg. Chars per Token     : 4.24
# ==================================================

# %%
verify_dataloader(val_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : dev-clean
# --------------------------------------------------
# Number of Batches        : 169
# Batch Size               : 16
# --------------------------------------------------
# Checking shapes of the data...
#
# Feature Shape            : [16, 3676, 80]
# Shifted Transcript Shape : [16, 104]
# Golden Transcript Shape  : [16, 104]
# Feature Lengths Shape    : [16]
# Transcript Lengths Shape : [16]
# --------------------------------------------------
# Max Feature Length       : 4081
# Max Transcript Length    : 138
# Avg. Chars per Token     : 4.17
# ==================================================

# %%
verify_dataloader(test_loader)
# Out:
# ==================================================
#              Dataloader Verification
# ==================================================
# Dataloader Partition     : test-clean
# --------------------------------------------------
# Number of Batches        : 164
# Batch Size               : 16
# --------------------------------------------------
# Checking shapes of the data...
#
# Feature Shape            : [16, 1556, 80]
# Feature Lengths Shape    : [16]
# --------------------------------------------------
# Max Feature Length       : 4370
# Max Transcript Length    : 0
# Avg. Chars per Token     : 0.00
# ==================================================

# %% [markdown]
# ## Calculate Max Lengths
# Calculating the maximum transcript length across your dataset is a crucial step when working with certain transformer models.
# -  We'll use sinusoidal positional encodings that must be precomputed up to a fixed maximum length.
# - This maximum length is a hyperparameter that determines:
#   - How long of a sequence your model can process
#   - The size of your positional encoding matrix
#   - Memory requirements during training and inference
# - `Requirements`: For this assignment, ensure your positional encodings can accommodate at least the longest sequence in your dataset to prevent truncation. However, you can set this value higher if you anticipate using your languagemodel to work with longer sequences in future tasks (hint: this might be useful for P2! 😉).
# - `NOTE`: We'll be using the same positional encoding matrix for all sequences in your dataset. Take this into account when setting your maximum length.

# %%
max_feat_len       = max(train_dataset.feat_max_len, val_dataset.feat_max_len, test_dataset.feat_max_len)
max_transcript_len = max(train_dataset.text_max_len, val_dataset.text_max_len, test_dataset.text_max_len)
max_len            = max(max_feat_len, max_transcript_len)

print("="*50)
print(f"{'Max Feature Length':<30} : {max_feat_len}")
print(f"{'Max Transcript Length':<30} : {max_transcript_len}")
print(f"{'Overall Max Length':<30} : {max_len}")
print("="*50)
# Out:
# ==================================================
# Max Feature Length             : 4370
# Max Transcript Length          : 138
# Overall Max Length             : 4370
# ==================================================

# %% [markdown]
# ## Wandb

# %%
wandb.login(key="wandb_key")
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /jet/home/awolosso/.netrc
# wandb: Currently logged in as: aawoloss (aawoloss-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Training
#
# Every time you run the trainer, it will create a new directory in the `expts` folder with the following structure:
# ```
# expts/
#     └── {run_name}/
#         ├── config.yaml
#         ├── model_arch.txt
#         ├── checkpoints/
#         │   ├── checkpoint-best-metric-model.pth
#         │   └── checkpoint-last-epoch-model.pth
#         ├── attn/
#         │   └── {attention visualizations}
#         └── text/
#             └── {generated text outputs}
# ```

# %% [markdown]
# ### Training Strategy 1: Cold-Start Trainer

# %% [markdown]
# #### Model Load (Default)

# %%
model_config = config['model'].copy()
model_config.update({
    'max_len': max_len,
    'num_classes': Tokenizer.vocab_size
})

model = EncoderDecoderTransformer(**model_config)

# Get some inputs from the train dataloader
for batch in train_loader:
    padded_feats, padded_shifted, padded_golden, feat_lengths, transcript_lengths = batch
    break

total_param = sum(p.numel() for p in model.parameters() if p.requires_grad)
assert total_param < 30_000_000, f"Total trainable parameters ({total_param}) exceeds 30 million."

model_stats = summary(model, input_data=[padded_feats, padded_shifted, feat_lengths, transcript_lengths])
print(model_stats)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# EncoderDecoderTransformer                     [16, 69, 5000]            --
# ├─SpeechEmbedding: 1-1                        [16, 346, 324]            --
# │    └─StackedBLSTMEmbedding: 2-1             [16, 346, 324]            --
# │    │    └─LSTM: 3-1                         [25379, 324]              316,224
# │    │    └─MaxPool1d: 3-2                    [16, 324, 693]            --
# │    │    └─LSTM: 3-3                         [8455, 324]               632,448
# │    │    └─MaxPool1d: 3-4                    [16, 324, 346]            --
# │    │    └─Linear: 3-5                       [16, 346, 324]            105,300
# │    │    └─Dropout: 3-6                      [16, 346, 324]            --
# ├─PositionalEncoding: 1-2                     [16, 346, 324]            --
# ├─Dropout: 1-3                                [16, 346, 324]            --
# ├─ModuleList: 1-4                             --                        --
# │    └─SelfAttentionEncoderLayer: 2-2         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-7           [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-8             [16, 346, 324]            1,330,124
# │    └─SelfAttentionEncoderLayer: 2-3         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-9           [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-10            [16, 346, 324]            1,330,124
# │    └─SelfAttentionEncoderLayer: 2-4         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-11          [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-12            [16, 346, 324]            1,330,124
# │    └─SelfAttentionEncoderLayer: 2-5         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-13          [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-14            [16, 346, 324]            1,330,124
# │    └─SelfAttentionEncoderLayer: 2-6         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-15          [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-16            [16, 346, 324]            1,330,124
# │    └─SelfAttentionEncoderLayer: 2-7         [16, 346, 324]            --
# │    │    └─SelfAttentionLayer: 3-17          [16, 346, 324]            421,848
# │    │    └─FeedForwardLayer: 3-18            [16, 346, 324]            1,330,124
# ├─LayerNorm: 1-5                              [16, 346, 324]            648
# ├─Sequential: 1-6                             [16, 346, 5000]           --
# │    └─Linear: 2-8                            [16, 346, 5000]           1,625,000
# │    └─LogSoftmax: 2-9                        [16, 346, 5000]           --
# ├─Embedding: 1-7                              [16, 69, 324]             1,620,000
# ├─PositionalEncoding: 1-8                     [16, 69, 324]             --
# ├─Dropout: 1-9                                [16, 69, 324]             --
# ├─ModuleList: 1-10                            --                        --
# │    └─CrossAttentionDecoderLayer: 2-10       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-19          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-20         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-21            [16, 69, 324]             1,330,124
# │    └─CrossAttentionDecoderLayer: 2-11       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-22          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-23         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-24            [16, 69, 324]             1,330,124
# │    └─CrossAttentionDecoderLayer: 2-12       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-25          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-26         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-27            [16, 69, 324]             1,330,124
# │    └─CrossAttentionDecoderLayer: 2-13       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-28          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-29         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-30            [16, 69, 324]             1,330,124
# │    └─CrossAttentionDecoderLayer: 2-14       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-31          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-32         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-33            [16, 69, 324]             1,330,124
# │    └─CrossAttentionDecoderLayer: 2-15       [16, 69, 324]             --
# │    │    └─SelfAttentionLayer: 3-34          [16, 69, 324]             421,848
# │    │    └─CrossAttentionLayer: 3-35         [16, 69, 324]             421,848
# │    │    └─FeedForwardLayer: 3-36            [16, 69, 324]             1,330,124
# ├─LayerNorm: 1-11                             [16, 69, 324]             648
# ├─Linear: 1-12                                [16, 69, 5000]            1,625,000
# ===============================================================================================
# Total params: 29,480,020
# Trainable params: 29,480,020
# Non-trainable params: 0
# Total mult-adds (Units.TERABYTES): 4.33
# ===============================================================================================
# Input size (MB): 10.65
# Forward/backward pass size (MB): 1367.42
# Params size (MB): 87.59
# Estimated Total Size (MB): 1465.67
# ===============================================================================================

# %% [markdown]
# #### LM Model from P1

# %%
# lm_model_config = lm_config['model'].copy()
# lm_max_len = 120
# lm_model_config.update({
#     'max_len': max_len,
#     'num_classes': Tokenizer.vocab_size
# })

# lm_model = DecoderOnlyTransformer(**lm_model_config)

# %% [markdown]
# #### Initialize Trainer
#
# If you need to reload the model from a checkpoint, you can do so by calling the `load_checkpoint` method.
#
# ```python
# checkpoint_path = "path/to/checkpoint.pth"
# trainer.load_checkpoint(checkpoint_path)
# ```

# %%
stages = [
            {
                # `Initial (1 layers)`:
                # This stage starts with a model with only 1 encoder and 1 decoder layer.
                # No freezing or regularization is applied.
                # It uses 20% of the training data.
                'name': 'Initial (1 Encoder + 1 Decoder layers)',
                'epochs': 5,
                'encoder_active_layers': list(range(1)),
                'decoder_active_layers': list(range(1)),
                'encoder_freeze': [False],
                'decoder_freeze': [False],
                'dropout': 0.0,
                'label_smoothing': 0.0,
                'data_subset': 0.2
            },
            {
                # `2 layers`:
                # This stage increases the number of layers to 2 for both the encoder and decoder.
                # The previous layer (encoder layer 1 and decoder layer 1) are frozen.
                # No regularization is applied.
                # It uses 20% of the training data.
                'name': '2 Encoder + 2 Decoder layers',
                'epochs': 5,
                'encoder_active_layers': list(range(2)),
                'decoder_active_layers': list(range(2)),
                'encoder_freeze': [True, False],
                'decoder_freeze': [True, False],
                'dropout': 0.0,
                'label_smoothing': 0.0,
                'data_subset': 0.2
            },
            {
                # `4 layers`:
                # This stage increases the number of layers to 4 for both the encoder and decoder.
                # The previous layers (encoder layers 1 and 2 and decoder layers 1 and 2) are frozen.
                # Dropout is set to 0.05 and label smoothing is set to 0.0.
                # It uses 20% of the training data.
                'name': '4 Encoder + 4 Decoder layers',
                'epochs': 5,
                'encoder_active_layers': list(range(4)),
                'decoder_active_layers': list(range(4)),
                'encoder_freeze': [True, True, False, False],
                'decoder_freeze': [True, True, False, False],
                'dropout': 0.05,
                'label_smoothing': 0.0,
                'data_subset': 0.2
            },
            {
                # `All 6 layers`:
                # This stage uses all 6 encoder and 6 decoder layers.
                # The 4 previous layers are frozen and the last 2 layers are trained.
                # Dropout is set to 0.1 and label smoothing is set to 0.0.
                # It uses 20% of the training data.
                'name': '6 Encoder + 6 Decoder layers',
                'epochs': 5,
                'encoder_active_layers': list(range(6)),
                'decoder_active_layers': list(range(6)),
                'encoder_freeze': [True, True, True, True, False, False],
                'decoder_freeze': [True, True, True, True, False, False],
                'dropout': 0.1,
                'label_smoothing': 0.0,
                'data_subset': 0.2
            },
            {
                # `Final (with label smoothing)`:
                # This stage uses all 6 encoder and 6 decoder layers.
                # All layers are unfrozen and trained.
                # Dropout is set to 0.1 and label smoothing is set to 0.1.
                # It uses 20% of the training data.
                'name': 'Final (with label smoothing)',
                'epochs': 5,
                'encoder_active_layers': list(range(6)),
                'decoder_active_layers': list(range(6)),
                'encoder_freeze': [False, False, False, False, False, False],
                'decoder_freeze': [False, False, False, False, False, False],
                'dropout': 0.1,
                'label_smoothing': 0.1,
                'data_subset': 0.2
            }
        ]

# %%
import datetime
run_name = f"P2_{datetime.datetime.now().strftime('%Y_%m_%d_%H_%M')}"
# run_name = "P2_2026_04_14_05_44"

# lm_config['training']['use_wandb'] = False
# lm_best_run = "P1_2026_04_13_09_00"
# lm_trainer = LMTrainer(
#     model=lm_model,
#     tokenizer=Tokenizer,
#     config=lm_config,
#     run_name=lm_best_run,
#     config_file="lm_config.yaml",
#     device=device
# )
# lm_trainer.load_checkpoint("checkpoint-best-metric-model.pth")

trainer = ASRTrainer(
    model=model,
    tokenizer=Tokenizer,
    config=config,
    run_name=run_name,
    config_file="config.yaml",
    device=device,
    #lm_model=lm_trainer.model
)

# trainer = ProgressiveTrainer(
#     model=model,
#     tokenizer=Tokenizer,
#     config=config,
#     run_name=run_name,
#     config_file="config.yaml",
#     device=device,
#     #lm_model=lm_trainer.model
# )
# Out:
# Using device: cuda
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/ocean/projects/cis260061p/awolosso/IDL/HW4/IDL26-HW4/wandb/run-20260425_054753-322nxlrb</code>
# Syncing run <strong><a href='https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2/runs/322nxlrb' target="_blank">P2_2026_04_25_05_47</a></strong> to <a href='https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2' target="_blank">https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2</a>
#  View run at <a href='https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2/runs/322nxlrb' target="_blank">https://wandb.ai/aawoloss-carnegie-mellon-university/IDL-HW4-P2/runs/322nxlrb</a>

# %%
# trainer.load_checkpoint("checkpoint-last-epoch-model.pth")
# trainer.load_checkpoint("/jet/home/awolosso/HW4/IDL26-HW4/expts/P2_2026_04_15_04_55/checkpoints/checkpoint-best-metric-model.pth", absolute_path=True)

# %% [markdown]
# ### Setup Optimizer and Scheduler
#
# You can set your own optimizer and scheduler by setting the class members in the `LMTrainer` class.
# Eg:
# ```python
# trainer.optimizer = optim.AdamW(model.parameters(), lr=config['optimizer']['lr'], weight_decay=config['optimizer']['weight_decay'])
# trainer.scheduler = optim.lr_scheduler.CosineAnnealingLR(trainer.optimizer, T_max=config['training']['epochs'])
# ```
#
# We also provide a utility function to create your own optimizer and scheduler with the congig and some extra bells and whistles. You are free to use it or not. Do read their code and documentation to understand how it works (`hw4lib/utils/*`).

# %% [markdown]
# #### Setting up the optimizer

# %%
trainer.optimizer = create_optimizer(
    model=model,
    opt_config=config['optimizer']
)
# Out:
# 🔧 Configuring Optimizer:
# ├── Type: ADAMW
# ├── Base LR: 0.001
# ├── Weight Decay: 1e-06
# ├── Parameter Groups:
# │   ├── Group: self_attn
# │   │   ├── LR: 0.0005
# │   │   └── Patterns: []
# │   ├── Group: ffn
# │   │   ├── LR: 0.0005
# │   │   └── Patterns: []
# │   └── Default Group (unmatched parameters)
# └── AdamW Specific:
#     ├── Betas: [0.9, 0.99]
#     ├── Epsilon: 1e-09
#     └── AMSGrad: False

# %%
# for i, g in enumerate(trainer.optimizer.param_groups):
#     print(f"Group {i}: {len(g['params'])} params")

# %%
# # Load checkpoint
# load_last_checkpoint_path = "/ocean/projects/cis260061p/awolosso/IDL/HW4/IDL26-HW4/expts/P2_2026_04_16_18_26/checkpoints/checkpoint-last-epoch-model.pth"
# checkpoint = torch.load(load_last_checkpoint_path, weights_only=False)
# print("Number of param groups in checkpoint:", len(checkpoint['optimizer_state_dict']['param_groups']))
# for i, group in enumerate(checkpoint['optimizer_state_dict']['param_groups']):
#     print(f"Group {i}: keys={group.keys()}, lr={group.get('lr')}, params count={len(group['params'])}")

# %% [markdown]
# #### Creating a test scheduler and plotting the learning rate schedule

# %%
test_scheduler = create_scheduler(
    optimizer=trainer.optimizer,
    scheduler_config=config['scheduler'],
    train_loader=train_loader,
    gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
)

# plot_lr_schedule(
#     scheduler=test_scheduler,
#     num_epochs=20,
#     train_loader=train_loader,
#     gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
# )
# Out:
# 📈 Configuring Learning Rate Scheduler:
# ├── Type: COSINE
# ├── Cosine Annealing Settings:
# │   ├── T_max: 15 epochs (26760 steps)
# │   └── Min LR: 0.0001
# ├── Warmup Settings:
# │   ├── Duration: 5 epochs (8920 steps)
# │   ├── Start Factor: 0.1
# │   └── End Factor: 1.0

# %% [markdown]
# #### Setting up the scheduler

# %%
trainer.scheduler = create_scheduler(
    optimizer=trainer.optimizer,
    scheduler_config=config['scheduler'],
    train_loader=train_loader,
    gradient_accumulation_steps=config['training']['gradient_accumulation_steps']
)
# Out:
# 📈 Configuring Learning Rate Scheduler:
# ├── Type: COSINE
# ├── Cosine Annealing Settings:
# │   ├── T_max: 15 epochs (26760 steps)
# │   └── Min LR: 0.0001
# ├── Warmup Settings:
# │   ├── Duration: 5 epochs (8920 steps)
# │   ├── Start Factor: 0.1
# │   └── End Factor: 1.0

# %% [markdown]
# #### Train
# - Set your epochs and start training!
# - `NOTE`: A `scheduler` gets initialized in this call based on the config.

# %%
trainer.load_checkpoint("/ocean/projects/cis260061p/awolosso/IDL/HW4/IDL26-HW4/expts/P2_2026_04_22_01_58/checkpoints/checkpoint-last-epoch-model.pth")
# trainer.load_checkpoint("/jet/home/awolosso/HW4/IDL26-HW4/expts/P2_2026_04_16_18_26/checkpoints/checkpoint-best-metric-model.pth")
# trainer.config['evaluation']["method"] = "greedy"
# trainer.load_checkpoint("checkpoint-best-metric-model.pth")
# trainer.scheduler._schedulers[1].eta_min = 1e-05
# trainer.scheduler._schedulers[1].T_max = 53520
# print( trainer.scheduler._schedulers[1].eta_min, trainer.scheduler._schedulers[1].T_max)
# Out:
# Checkpoint loaded from epoch 43
# Successfully loaded: model, optimizer, scheduler, scaler, training_state

# %%
trainer.train(train_loader, val_loader, epochs=300)
#trainer.progressive_train(train_loader, val_loader, stages)
# Out:
# 📊 Metrics (Epoch 43):
# ├── TRAIN:
# │   ├── ce_loss: 1.3827
# │   ├── ctc_loss: 0.5412
# │   ├── joint_loss: 1.4909
# │   ├── perplexity_char: 1.3858
# │   └── perplexity_token: 3.9855
# └── VAL:
#     ├── ce_loss: 1.9904
#     ├── cer: 11.9211
#     ├── ctc_loss: 1.6811
#     ├── joint_loss: 2.3266
#     ├── wer: 21.2970
#     └── word_dist: 14.8032
# └── TRAINING:
#     └── learning_rate: 0.000122
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 44):
# ├── TRAIN:
# │   ├── ce_loss: 1.3756
# │   ├── ctc_loss: 0.5207
# │   ├── joint_loss: 1.4798
# │   ├── perplexity_char: 1.3835
# │   └── perplexity_token: 3.9575
# └── VAL:
#     ├── ce_loss: 1.9875
#     ├── cer: 11.8933
#     ├── ctc_loss: 1.6871
#     ├── joint_loss: 2.3249
#     ├── wer: 21.2088
#     └── word_dist: 14.6445
# └── TRAINING:
#     └── learning_rate: 0.000110
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 45):
# ├── TRAIN:
# │   ├── ce_loss: 1.3642
# │   ├── ctc_loss: 0.5021
# │   ├── joint_loss: 1.4646
# │   ├── perplexity_char: 1.3798
# │   └── perplexity_token: 3.9124
# └── VAL:
#     ├── ce_loss: 1.9873
#     ├── cer: 11.9058
#     ├── ctc_loss: 1.6964
#     ├── joint_loss: 2.3266
#     ├── wer: 21.1591
#     └── word_dist: 14.7858
# └── TRAINING:
#     └── learning_rate: 0.000102
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 46):
# ├── TRAIN:
# │   ├── ce_loss: 1.3498
# │   ├── ctc_loss: 0.4868
# │   ├── joint_loss: 1.4472
# │   ├── perplexity_char: 1.3751
# │   └── perplexity_token: 3.8568
# └── VAL:
#     ├── ce_loss: 1.9882
#     ├── cer: 12.0216
#     ├── ctc_loss: 1.6972
#     ├── joint_loss: 2.3276
#     ├── wer: 21.3136
#     └── word_dist: 14.9908
# └── TRAINING:
#     └── learning_rate: 0.001000
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 47):
# ├── TRAIN:
# │   ├── ce_loss: 1.6143
# │   ├── ctc_loss: 0.7995
# │   ├── joint_loss: 1.7742
# │   ├── perplexity_char: 1.4637
# │   └── perplexity_token: 5.0243
# └── VAL:
#     ├── ce_loss: 2.1628
#     ├── cer: 14.5551
#     ├── ctc_loss: 1.7815
#     ├── joint_loss: 2.5191
#     ├── wer: 25.4954
#     └── word_dist: 17.5165
# └── TRAINING:
#     └── learning_rate: 0.000999
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 48):
# ├── TRAIN:
# │   ├── ce_loss: 1.6225
# │   ├── ctc_loss: 0.8237
# │   ├── joint_loss: 1.7872
# │   ├── perplexity_char: 1.4665
# │   └── perplexity_token: 5.0655
# └── VAL:
#     ├── ce_loss: 2.1898
#     ├── cer: 15.7358
#     ├── ctc_loss: 1.7955
#     ├── joint_loss: 2.5489
#     ├── wer: 27.2104
#     └── word_dist: 18.7451
# └── TRAINING:
#     └── learning_rate: 0.000998
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 49):
# ├── TRAIN:
# │   ├── ce_loss: 1.6634
# │   ├── ctc_loss: 0.8920
# │   ├── joint_loss: 1.8418
# │   ├── perplexity_char: 1.4807
# │   └── perplexity_token: 5.2770
# └── VAL:
#     ├── ce_loss: 2.1129
#     ├── cer: 14.4455
#     ├── ctc_loss: 1.7224
#     ├── joint_loss: 2.4574
#     ├── wer: 25.2803
#     └── word_dist: 17.4269
# └── TRAINING:
#     └── learning_rate: 0.000994
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 50):
# ├── TRAIN:
# │   ├── ce_loss: 1.6261
# │   ├── ctc_loss: 0.8443
# │   ├── joint_loss: 1.7949
# │   ├── perplexity_char: 1.4678
# │   └── perplexity_token: 5.0839
# └── VAL:
#     ├── ce_loss: 2.1236
#     ├── cer: 14.7849
#     ├── ctc_loss: 1.7444
#     ├── joint_loss: 2.4724
#     ├── wer: 25.7196
#     └── word_dist: 17.7743
# └── TRAINING:
#     └── learning_rate: 0.000990
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 51):
# ├── TRAIN:
# │   ├── ce_loss: 1.5590
# │   ├── ctc_loss: 0.7541
# │   ├── joint_loss: 1.7098
# │   ├── perplexity_char: 1.4447
# │   └── perplexity_token: 4.7541
# └── VAL:
#     ├── ce_loss: 2.0920
#     ├── cer: 13.4651
#     ├── ctc_loss: 1.7134
#     ├── joint_loss: 2.4346
#     ├── wer: 24.0157
#     └── word_dist: 16.3385
# └── TRAINING:
#     └── learning_rate: 0.000985
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 52):
# ├── TRAIN:
# │   ├── ce_loss: 1.5836
# │   ├── ctc_loss: 0.7879
# │   ├── joint_loss: 1.7412
# │   ├── perplexity_char: 1.4531
# │   └── perplexity_token: 4.8724
# └── VAL:
#     ├── ce_loss: 2.1429
#     ├── cer: 14.2327
#     ├── ctc_loss: 1.7535
#     ├── joint_loss: 2.4936
#     ├── wer: 24.9366
#     └── word_dist: 17.1694
# └── TRAINING:
#     └── learning_rate: 0.000978
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 53):
# ├── TRAIN:
# │   ├── ce_loss: 1.6129
# │   ├── ctc_loss: 0.8106
# │   ├── joint_loss: 1.7750
# │   ├── perplexity_char: 1.4632
# │   └── perplexity_token: 5.0173
# └── VAL:
#     ├── ce_loss: 2.0949
#     ├── cer: 13.4176
#     ├── ctc_loss: 1.6924
#     ├── joint_loss: 2.4334
#     ├── wer: 24.0579
#     └── word_dist: 16.3574
# └── TRAINING:
#     └── learning_rate: 0.000970
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 54):
# ├── TRAIN:
# │   ├── ce_loss: 1.5672
# │   ├── ctc_loss: 0.7661
# │   ├── joint_loss: 1.7204
# │   ├── perplexity_char: 1.4475
# │   └── perplexity_token: 4.7931
# └── VAL:
#     ├── ce_loss: 2.0894
#     ├── cer: 13.2980
#     ├── ctc_loss: 1.7089
#     ├── joint_loss: 2.4311
#     ├── wer: 23.5929
#     └── word_dist: 16.0229
# └── TRAINING:
#     └── learning_rate: 0.000961
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 55):
# ├── TRAIN:
# │   ├── ce_loss: 1.5977
# │   ├── ctc_loss: 0.7844
# │   ├── joint_loss: 1.7546
# │   ├── perplexity_char: 1.4580
# │   └── perplexity_token: 4.9417
# └── VAL:
#     ├── ce_loss: 2.1129
#     ├── cer: 14.0063
#     ├── ctc_loss: 1.7238
#     ├── joint_loss: 2.4577
#     ├── wer: 24.8778
#     └── word_dist: 16.8139
# └── TRAINING:
#     └── learning_rate: 0.000951
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 56):
# ├── TRAIN:
# │   ├── ce_loss: 1.5552
# │   ├── ctc_loss: 0.7260
# │   ├── joint_loss: 1.7004
# │   ├── perplexity_char: 1.4434
# │   └── perplexity_token: 4.7362
# └── VAL:
#     ├── ce_loss: 2.0838
#     ├── cer: 13.4863
#     ├── ctc_loss: 1.6994
#     ├── joint_loss: 2.4237
#     ├── wer: 23.5929
#     └── word_dist: 16.4932
# └── TRAINING:
#     └── learning_rate: 0.000940
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 57):
# ├── TRAIN:
# │   ├── ce_loss: 1.5446
# │   ├── ctc_loss: 0.6881
# │   ├── joint_loss: 1.6822
# │   ├── perplexity_char: 1.4398
# │   └── perplexity_token: 4.6861
# └── VAL:
#     ├── ce_loss: 2.0750
#     ├── cer: 13.4863
#     ├── ctc_loss: 1.7078
#     ├── joint_loss: 2.4166
#     ├── wer: 23.7969
#     └── word_dist: 16.4147
# └── TRAINING:
#     └── learning_rate: 0.000927
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 58):
# ├── TRAIN:
# │   ├── ce_loss: 1.5586
# │   ├── ctc_loss: 0.7175
# │   ├── joint_loss: 1.7021
# │   ├── perplexity_char: 1.4446
# │   └── perplexity_token: 4.7524
# └── VAL:
#     ├── ce_loss: 2.0956
#     ├── cer: 13.5882
#     ├── ctc_loss: 1.6903
#     ├── joint_loss: 2.4336
#     ├── wer: 23.8392
#     └── word_dist: 16.4395
# └── TRAINING:
#     └── learning_rate: 0.000914
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 59):
# ├── TRAIN:
# │   ├── ce_loss: 1.5347
# │   ├── ctc_loss: 0.6748
# │   ├── joint_loss: 1.6696
# │   ├── perplexity_char: 1.4364
# │   └── perplexity_token: 4.6398
# └── VAL:
#     ├── ce_loss: 2.0680
#     ├── cer: 12.8262
#     ├── ctc_loss: 1.6845
#     ├── joint_loss: 2.4049
#     ├── wer: 22.9844
#     └── word_dist: 15.6230
# └── TRAINING:
#     └── learning_rate: 0.000900
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 60):
# ├── TRAIN:
# │   ├── ce_loss: 1.5413
# │   ├── ctc_loss: 0.6794
# │   ├── joint_loss: 1.6772
# │   ├── perplexity_char: 1.4387
# │   └── perplexity_token: 4.6708
# └── VAL:
#     ├── ce_loss: 2.0879
#     ├── cer: 13.3154
#     ├── ctc_loss: 1.6956
#     ├── joint_loss: 2.4270
#     ├── wer: 23.5322
#     └── word_dist: 16.2967
# └── TRAINING:
#     └── learning_rate: 0.000884
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 61):
# ├── TRAIN:
# │   ├── ce_loss: 1.5052
# │   ├── ctc_loss: 0.6219
# │   ├── joint_loss: 1.6296
# │   ├── perplexity_char: 1.4265
# │   └── perplexity_token: 4.5052
# └── VAL:
#     ├── ce_loss: 2.0621
#     ├── cer: 13.3948
#     ├── ctc_loss: 1.6898
#     ├── joint_loss: 2.4000
#     ├── wer: 23.4458
#     └── word_dist: 16.4743
# └── TRAINING:
#     └── learning_rate: 0.000868
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 62):
# ├── TRAIN:
# │   ├── ce_loss: 1.4751
# │   ├── ctc_loss: 0.5851
# │   ├── joint_loss: 1.5921
# │   ├── perplexity_char: 1.4164
# │   └── perplexity_token: 4.3716
# └── VAL:
#     ├── ce_loss: 2.0328
#     ├── cer: 12.3790
#     ├── ctc_loss: 1.6917
#     ├── joint_loss: 2.3712
#     ├── wer: 22.0819
#     └── word_dist: 15.2619
# └── TRAINING:
#     └── learning_rate: 0.000851
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 63):
# ├── TRAIN:
# │   ├── ce_loss: 1.4440
# │   ├── ctc_loss: 0.5384
# │   ├── joint_loss: 1.5517
# │   ├── perplexity_char: 1.4060
# │   └── perplexity_token: 4.2378
# └── VAL:
#     ├── ce_loss: 2.0544
#     ├── cer: 13.2291
#     ├── ctc_loss: 1.7036
#     ├── joint_loss: 2.3952
#     ├── wer: 23.3447
#     └── word_dist: 16.1998
# └── TRAINING:
#     └── learning_rate: 0.000833
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 64):
# ├── TRAIN:
# │   ├── ce_loss: 1.4634
# │   ├── ctc_loss: 0.5571
# │   ├── joint_loss: 1.5748
# │   ├── perplexity_char: 1.4125
# │   └── perplexity_token: 4.3207
# └── VAL:
#     ├── ce_loss: 2.0372
#     ├── cer: 12.3138
#     ├── ctc_loss: 1.7008
#     ├── joint_loss: 2.3774
#     ├── wer: 21.9202
#     └── word_dist: 15.2294
# └── TRAINING:
#     └── learning_rate: 0.000815
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 65):
# ├── TRAIN:
# │   ├── ce_loss: 1.4503
# │   ├── ctc_loss: 0.5201
# │   ├── joint_loss: 1.5543
# │   ├── perplexity_char: 1.4081
# │   └── perplexity_token: 4.2643
# └── VAL:
#     ├── ce_loss: 2.0438
#     ├── cer: 12.0226
#     ├── ctc_loss: 1.6907
#     ├── joint_loss: 2.3819
#     ├── wer: 21.5544
#     └── word_dist: 14.8017
# └── TRAINING:
#     └── learning_rate: 0.000795
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 66):
# ├── TRAIN:
# │   ├── ce_loss: 1.4390
# │   ├── ctc_loss: 0.5124
# │   ├── joint_loss: 1.5415
# │   ├── perplexity_char: 1.4044
# │   └── perplexity_token: 4.2164
# └── VAL:
#     ├── ce_loss: 2.0483
#     ├── cer: 12.2334
#     ├── ctc_loss: 1.6982
#     ├── joint_loss: 2.3879
#     ├── wer: 21.8448
#     └── word_dist: 15.0499
# └── TRAINING:
#     └── learning_rate: 0.000775
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 67):
# ├── TRAIN:
# │   ├── ce_loss: 1.4427
# │   ├── ctc_loss: 0.5039
# │   ├── joint_loss: 1.5435
# │   ├── perplexity_char: 1.4056
# │   └── perplexity_token: 4.2320
# └── VAL:
#     ├── ce_loss: 2.0317
#     ├── cer: 12.3204
#     ├── ctc_loss: 1.6993
#     ├── joint_loss: 2.3715
#     ├── wer: 22.0341
#     └── word_dist: 15.3163
# └── TRAINING:
#     └── learning_rate: 0.000754
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 68):
# ├── TRAIN:
# │   ├── ce_loss: 1.4412
# │   ├── ctc_loss: 0.4813
# │   ├── joint_loss: 1.5374
# │   ├── perplexity_char: 1.4051
# │   └── perplexity_token: 4.2256
# └── VAL:
#     ├── ce_loss: 2.0514
#     ├── cer: 12.9690
#     ├── ctc_loss: 1.7097
#     ├── joint_loss: 2.3933
#     ├── wer: 22.5267
#     └── word_dist: 16.0773
# └── TRAINING:
#     └── learning_rate: 0.000733
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 69):
# ├── TRAIN:
# │   ├── ce_loss: 1.4253
# │   ├── ctc_loss: 0.4590
# │   ├── joint_loss: 1.5171
# │   ├── perplexity_char: 1.3998
# │   └── perplexity_token: 4.1591
# └── VAL:
#     ├── ce_loss: 2.0283
#     ├── cer: 12.0365
#     ├── ctc_loss: 1.7050
#     ├── joint_loss: 2.3693
#     ├── wer: 21.5764
#     └── word_dist: 14.9438
# └── TRAINING:
#     └── learning_rate: 0.000711
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 70):
# ├── TRAIN:
# │   ├── ce_loss: 1.4117
# │   ├── ctc_loss: 0.4430
# │   ├── joint_loss: 1.5003
# │   ├── perplexity_char: 1.3953
# │   └── perplexity_token: 4.1028
# └── VAL:
#     ├── ce_loss: 2.0416
#     ├── cer: 12.2702
#     ├── ctc_loss: 1.7149
#     ├── joint_loss: 2.3845
#     ├── wer: 21.8944
#     └── word_dist: 14.9826
# └── TRAINING:
#     └── learning_rate: 0.000689
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 71):
# ├── TRAIN:
# │   ├── ce_loss: 1.4183
# │   ├── ctc_loss: 0.4301
# │   ├── joint_loss: 1.5043
# │   ├── perplexity_char: 1.3975
# │   └── perplexity_token: 4.1301
# └── VAL:
#     ├── ce_loss: 2.0451
#     ├── cer: 12.3086
#     ├── ctc_loss: 1.7330
#     ├── joint_loss: 2.3917
#     ├── wer: 21.9624
#     └── word_dist: 15.1476
# └── TRAINING:
#     └── learning_rate: 0.000666
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 72):
# ├── TRAIN:
# │   ├── ce_loss: 1.4148
# │   ├── ctc_loss: 0.4234
# │   ├── joint_loss: 1.4995
# │   ├── perplexity_char: 1.3964
# │   └── perplexity_token: 4.1155
# └── VAL:
#     ├── ce_loss: 2.0552
#     ├── cer: 12.4494
#     ├── ctc_loss: 1.7447
#     ├── joint_loss: 2.4041
#     ├── wer: 22.0782
#     └── word_dist: 15.5549
# └── TRAINING:
#     └── learning_rate: 0.000644
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 73):
# ├── TRAIN:
# │   ├── ce_loss: 1.4009
# │   ├── ctc_loss: 0.4056
# │   ├── joint_loss: 1.4821
# │   ├── perplexity_char: 1.3918
# │   └── perplexity_token: 4.0590
# └── VAL:
#     ├── ce_loss: 2.0475
#     ├── cer: 12.1291
#     ├── ctc_loss: 1.7507
#     ├── joint_loss: 2.3977
#     ├── wer: 21.6794
#     └── word_dist: 14.9930
# └── TRAINING:
#     └── learning_rate: 0.000620
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 74):
# ├── TRAIN:
# │   ├── ce_loss: 1.3944
# │   ├── ctc_loss: 0.3945
# │   ├── joint_loss: 1.4733
# │   ├── perplexity_char: 1.3897
# │   └── perplexity_token: 4.0325
# └── VAL:
#     ├── ce_loss: 2.0471
#     ├── cer: 12.0667
#     ├── ctc_loss: 1.7477
#     ├── joint_loss: 2.3966
#     ├── wer: 21.4919
#     └── word_dist: 15.0425
# └── TRAINING:
#     └── learning_rate: 0.000597
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 75):
# ├── TRAIN:
# │   ├── ce_loss: 1.3814
# │   ├── ctc_loss: 0.3657
# │   ├── joint_loss: 1.4545
# │   ├── perplexity_char: 1.3854
# │   └── perplexity_token: 3.9804
# └── VAL:
#     ├── ce_loss: 2.0300
#     ├── cer: 11.6430
#     ├── ctc_loss: 1.7313
#     ├── joint_loss: 2.3763
#     ├── wer: 20.8503
#     └── word_dist: 14.4895
# └── TRAINING:
#     └── learning_rate: 0.000574
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 76):
# ├── TRAIN:
# │   ├── ce_loss: 1.3978
# │   ├── ctc_loss: 0.3808
# │   ├── joint_loss: 1.4740
# │   ├── perplexity_char: 1.3908
# │   └── perplexity_token: 4.0464
# └── VAL:
#     ├── ce_loss: 2.0588
#     ├── cer: 12.5045
#     ├── ctc_loss: 1.7530
#     ├── joint_loss: 2.4094
#     ├── wer: 22.3705
#     └── word_dist: 15.3848
# └── TRAINING:
#     └── learning_rate: 0.000550
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 77):
# ├── TRAIN:
# │   ├── ce_loss: 1.3926
# │   ├── ctc_loss: 0.3732
# │   ├── joint_loss: 1.4673
# │   ├── perplexity_char: 1.3891
# │   └── perplexity_token: 4.0254
# └── VAL:
#     ├── ce_loss: 2.0531
#     ├── cer: 11.9921
#     ├── ctc_loss: 1.7787
#     ├── joint_loss: 2.4089
#     ├── wer: 21.4661
#     └── word_dist: 14.8209
# └── TRAINING:
#     └── learning_rate: 0.000526
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 78):
# ├── TRAIN:
# │   ├── ce_loss: 1.3742
# │   ├── ctc_loss: 0.3460
# │   ├── joint_loss: 1.4434
# │   ├── perplexity_char: 1.3830
# │   └── perplexity_token: 3.9518
# └── VAL:
#     ├── ce_loss: 2.0252
#     ├── cer: 11.7037
#     ├── ctc_loss: 1.7491
#     ├── joint_loss: 2.3750
#     ├── wer: 20.8595
#     └── word_dist: 14.5886
# └── TRAINING:
#     └── learning_rate: 0.000503
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# IOPub message rate exceeded.██▊                                 | 407/1784 [01:36<05:19,  4.31it/s, acc_step=1/1, ce_loss=1.3476, ctc_loss=0.3040, joint_loss=1.4084, perplexity=3.8482]
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 📊 Metrics (Epoch 79):
# ├── TRAIN:
# │   ├── ce_loss: 1.3637
# │   ├── ctc_loss: 0.3251
# │   ├── joint_loss: 1.4287
# │   ├── perplexity_char: 1.3796
# │   └── perplexity_token: 3.9107
# └── VAL:
#     ├── ce_loss: 2.0313
#     ├── cer: 11.8684
#     ├── ctc_loss: 1.7667
#     ├── joint_loss: 2.3846
#     ├── wer: 21.2952
#     └── word_dist: 14.7529
# └── TRAINING:
#     └── learning_rate: 0.000480
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# IOPub message rate exceeded.███████████████████████████▍       | 1461/1784 [05:44<01:16,  4.25it/s, acc_step=1/1, ce_loss=1.3527, ctc_loss=0.3150, joint_loss=1.4157, perplexity=3.8679]
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 📊 Metrics (Epoch 80):
# ├── TRAIN:
# │   ├── ce_loss: 1.3516
# │   ├── ctc_loss: 0.3144
# │   ├── joint_loss: 1.4145
# │   ├── perplexity_char: 1.3757
# │   └── perplexity_token: 3.8636
# └── VAL:
#     ├── ce_loss: 2.0234
#     ├── cer: 11.6690
#     ├── ctc_loss: 1.7591
#     ├── joint_loss: 2.3752
#     ├── wer: 20.9514
#     └── word_dist: 14.4924
# └── TRAINING:
#     └── learning_rate: 0.000456
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 81):
# ├── TRAIN:
# │   ├── ce_loss: 1.3438
# │   ├── ctc_loss: 0.2836
# │   ├── joint_loss: 1.4005
# │   ├── perplexity_char: 1.3732
# │   └── perplexity_token: 3.8335
# └── VAL:
#     ├── ce_loss: 2.0403
#     ├── cer: 11.7737
#     ├── ctc_loss: 1.8000
#     ├── joint_loss: 2.4003
#     ├── wer: 21.1996
#     └── word_dist: 14.7314
# └── TRAINING:
#     └── learning_rate: 0.000434
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 82):
# ├── TRAIN:
# │   ├── ce_loss: 1.3546
# │   ├── ctc_loss: 0.3035
# │   ├── joint_loss: 1.4153
# │   ├── perplexity_char: 1.3767
# │   └── perplexity_token: 3.8751
# └── VAL:
#     ├── ce_loss: 2.0260
#     ├── cer: 11.4926
#     ├── ctc_loss: 1.7932
#     ├── joint_loss: 2.3846
#     ├── wer: 20.7143
#     └── word_dist: 14.3951
# └── TRAINING:
#     └── learning_rate: 0.000411
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 83):
# ├── TRAIN:
# │   ├── ce_loss: 1.3634
# │   ├── ctc_loss: 0.2981
# │   ├── joint_loss: 1.4231
# │   ├── perplexity_char: 1.3795
# │   └── perplexity_token: 3.9096
# └── VAL:
#     ├── ce_loss: 2.0372
#     ├── cer: 11.7113
#     ├── ctc_loss: 1.8120
#     ├── joint_loss: 2.3996
#     ├── wer: 21.0654
#     └── word_dist: 14.5760
# └── TRAINING:
#     └── learning_rate: 0.000389
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 84):
# ├── TRAIN:
# │   ├── ce_loss: 1.3630
# │   ├── ctc_loss: 0.2944
# │   ├── joint_loss: 1.4219
# │   ├── perplexity_char: 1.3794
# │   └── perplexity_token: 3.9078
# └── VAL:
#     ├── ce_loss: 2.0509
#     ├── cer: 12.1429
#     ├── ctc_loss: 1.8277
#     ├── joint_loss: 2.4165
#     ├── wer: 21.8025
#     └── word_dist: 15.1528
# └── TRAINING:
#     └── learning_rate: 0.000367
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 85):
# ├── TRAIN:
# │   ├── ce_loss: 1.3474
# │   ├── ctc_loss: 0.2817
# │   ├── joint_loss: 1.4037
# │   ├── perplexity_char: 1.3743
# │   └── perplexity_token: 3.8473
# └── VAL:
#     ├── ce_loss: 2.0314
#     ├── cer: 11.6520
#     ├── ctc_loss: 1.8042
#     ├── joint_loss: 2.3923
#     ├── wer: 21.0728
#     └── word_dist: 14.5420
# └── TRAINING:
#     └── learning_rate: 0.000346
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 86):
# ├── TRAIN:
# │   ├── ce_loss: 1.3288
# │   ├── ctc_loss: 0.2554
# │   ├── joint_loss: 1.3798
# │   ├── perplexity_char: 1.3683
# │   └── perplexity_token: 3.7763
# └── VAL:
#     ├── ce_loss: 2.0298
#     ├── cer: 11.5668
#     ├── ctc_loss: 1.8319
#     ├── joint_loss: 2.3962
#     ├── wer: 20.9183
#     └── word_dist: 14.4406
# └── TRAINING:
#     └── learning_rate: 0.000325
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 87):
# ├── TRAIN:
# │   ├── ce_loss: 1.3209
# │   ├── ctc_loss: 0.2432
# │   ├── joint_loss: 1.3695
# │   ├── perplexity_char: 1.3658
# │   └── perplexity_token: 3.7466
# └── VAL:
#     ├── ce_loss: 2.0453
#     ├── cer: 11.5550
#     ├── ctc_loss: 1.8388
#     ├── joint_loss: 2.4130
#     ├── wer: 20.8411
#     └── word_dist: 14.3566
# └── TRAINING:
#     └── learning_rate: 0.000305
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 88):
# ├── TRAIN:
# │   ├── ce_loss: 1.3310
# │   ├── ctc_loss: 0.2470
# │   ├── joint_loss: 1.3804
# │   ├── perplexity_char: 1.3690
# │   └── perplexity_token: 3.7849
# └── VAL:
#     ├── ce_loss: 2.0487
#     ├── cer: 11.8295
#     ├── ctc_loss: 1.8554
#     ├── joint_loss: 2.4197
#     ├── wer: 21.2198
#     └── word_dist: 14.7740
# └── TRAINING:
#     └── learning_rate: 0.000285
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 89):
# ├── TRAIN:
# │   ├── ce_loss: 1.3262
# │   ├── ctc_loss: 0.2437
# │   ├── joint_loss: 1.3749
# │   ├── perplexity_char: 1.3675
# │   └── perplexity_token: 3.7665
# └── VAL:
#     ├── ce_loss: 2.0444
#     ├── cer: 11.4693
#     ├── ctc_loss: 1.8624
#     ├── joint_loss: 2.4168
#     ├── wer: 20.7842
#     └── word_dist: 14.2941
# └── TRAINING:
#     └── learning_rate: 0.000267
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 90):
# ├── TRAIN:
# │   ├── ce_loss: 1.3214
# │   ├── ctc_loss: 0.2259
# │   ├── joint_loss: 1.3666
# │   ├── perplexity_char: 1.3659
# │   └── perplexity_token: 3.7487
# └── VAL:
#     ├── ce_loss: 2.0402
#     ├── cer: 11.5865
#     ├── ctc_loss: 1.8733
#     ├── joint_loss: 2.4148
#     ├── wer: 20.8945
#     └── word_dist: 14.4062
# └── TRAINING:
#     └── learning_rate: 0.000249
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 91):
# ├── TRAIN:
# │   ├── ce_loss: 1.3178
# │   ├── ctc_loss: 0.2196
# │   ├── joint_loss: 1.3617
# │   ├── perplexity_char: 1.3648
# │   └── perplexity_token: 3.7351
# └── VAL:
#     ├── ce_loss: 2.0452
#     ├── cer: 11.5030
#     ├── ctc_loss: 1.8845
#     ├── joint_loss: 2.4221
#     ├── wer: 20.7382
#     └── word_dist: 14.3792
# └── TRAINING:
#     └── learning_rate: 0.000232
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 92):
# ├── TRAIN:
# │   ├── ce_loss: 1.3100
# │   ├── ctc_loss: 0.2076
# │   ├── joint_loss: 1.3515
# │   ├── perplexity_char: 1.3622
# │   └── perplexity_token: 3.7060
# └── VAL:
#     ├── ce_loss: 2.0313
#     ├── cer: 11.3154
#     ├── ctc_loss: 1.9029
#     ├── joint_loss: 2.4118
#     ├── wer: 20.3651
#     └── word_dist: 14.1968
# └── TRAINING:
#     └── learning_rate: 0.000216
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# 📊 Metrics (Epoch 93):
# ├── TRAIN:
# │   ├── ce_loss: 1.3133
# │   ├── ctc_loss: 0.2075
# │   ├── joint_loss: 1.3547
# │   ├── perplexity_char: 1.3633
# │   └── perplexity_token: 3.7182
# └── VAL:
#     ├── ce_loss: 2.0227
#     ├── cer: 11.4184
#     ├── ctc_loss: 1.8619
#     ├── joint_loss: 2.3950
#     ├── wer: 20.5893
#     └── word_dist: 14.3222
# └── TRAINING:
#     └── learning_rate: 0.000200
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# [Training ASR]:   0%|                                                                                                                                          | 0/1784 [00:00<?, ?it/s]

# %%
trainer.load_checkpoint("checkpoint-best-metric-model.pth")

# %%
# Define the recognition config: Greedy search
recognition_config = {
    'num_batches': None,
    'temperature': 1.0,
    'repeat_penalty': 1.0,
    'lm_weight': None,
    'lm_model': None,
    'beam_width': 10, # Beam width of 1 reverts to greedy
}

# Recognize with the shallow fusion config
config_name = "test"
print(f"Evaluating with {config_name} config")
results = trainer.recognize(test_loader, recognition_config, config_name=config_name, max_length=max_transcript_len)


# Calculate metrics on full batch
generated = [r['generated'] for r in results]
results_df = pd.DataFrame(
    {
        'id': range(len(generated)),
        'transcription': generated
    }
)

# Cleanup (Will end wandb run)
trainer.cleanup()

# %% [markdown]
# ## Submit to Kaggle

# %%
results_df.to_csv("results.csv", index=False)
submission_message = "First submission for HW4P2"
api.competition_submit(file_name="results.csv", message=submission_message, competition="11785-hw-4-p-2-asr-with-transformer-spring-2026")
# Out:
# %|                                                                                                                                                        | 0.00/283k [00:00<?, ?B/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 283k/283k [00:00<00:00, 753kB/s]
# {"message": "Successfully submitted to 11785 HW4P2 ASR with Transformer Spring 2026", "ref": 51791007}

# %% [markdown]
# #### **Manual submission (optional)**
#
# If automatic submission is unavailable, download the CSV and submit it manually using one of the options below.
#
# ##### **Kaggle**
#
# * After running the cell above, the file **`results.csv`** will be saved in:
#   **Right sidebar → Output → `kaggle/working/`**
# * If the file does not appear right away, click the **refresh icon** in the top-right corner of the Output panel.
# * Once the file is visible, **right-click → Download**.
# * Upload the downloaded file to the **Kaggle competition submission page**.
#
# ---
#
# ##### **Colab**
#
# ```python
# from google.colab import files
# files.download("results.csv")
# ```
#
# ##### **PSC**
#
# * Open the left file browser.
# * Navigate to:
#   `/jet/home/<your_username>/`
# * Locate **`results.csv`**.
# * Right-click the file and select **Download**.
# * If the file does not appear immediately, refresh the file browser.

# %% [markdown]
# ## 📦 Autolab Submission Instructions (Read Carefully)
#
# This section guides you through creating and submitting your **final Autolab code submission**.
# Please follow each step in order. Skipping steps may result in an incomplete or invalid submission.
#
# ### ⏰ Important Deadlines
#
# * **Kaggle Final Deadline:** See the course schedule
# * **Autolab Code Submission Deadline:**
#   **48 hours after** the Kaggle deadline (or the same day as your Slack Kaggle submission, if applicable)
#
# You must submit **both**:
#
# 1. A valid Kaggle submission
# 2. A complete Autolab code submission zip

# %% [markdown]
# Please assign your **final trained model** to the global variable `MODEL`.
#
# We will use this variable to automatically generate a file named
# `model_metadata.json`, which records important information about your model (such as parameter count and architecture).
#
# #### 🔴 Important Requirements
#
# * **`MODEL` must be the exact model used for your best Kaggle submission**
# * This step is **required** for grading and audit purposes
# * If the model does not match your Kaggle submission, your score may be invalidated
#
# #### 🕒 When to Do This
#
# * Run this cell **only after you have finished training** your final model
# * Do **not** retrain or modify the model after assigning it to `MODEL`

# %%
MODEL = trainer.model # TODO: Initialize to your tained model

# %% [markdown]
# ### Step 2: Complete the README Section

# %% [markdown]
# Fill in the `README` variable with a brief description of your work:
#
# * **Model**: Architecture and key design choices
# * **Training Strategy**: Optimizer, scheduler, loss, etc.
# * **Augmentations**: If used (omit if not)
# * **Notebook Execution**: Any instructions needed to run your notebook
#
# This README will be included in your submission zip.

# %%
README = """
- **Model**: The model had 6 encoder and 6 decoder layers as in the original paper, 4 attention heads in both encoder and decoder. We increased
the model dimension d_model to 324 and also the feed-forward dimension to 2048 for both encoder and decoder.
- **Training Strategy**: We used AdamW as optimizer with an increased base learning rate of 0.001, CosineAnnealingLR as scheduler with a T_max=15
and minimum learning rate of 0.0001. We also enabled an exponential warmup for 5 epochs with start and end factor of 0.1 and 1.0 respectively. We
also added the pre-trained model of P1 to guide the decoding prediction of our model.
- **Augmentations**: No data augmentation was applied.
- **Notebook Execution**: No specific instructions required to run the notebook.
"""

# %% [markdown]
# ### Step 3: Provide Required Credentials

# %% [markdown]
# Ensure the following variables are correctly set:
#
# * `KAGGLE_USERNAME`
# * `KAGGLE_API_KEY`
# * `WANDB_API_KEY`
# * `WANDB_USERNAME_OR_TEAMNAME`
# * `WANDB_PROJECT`
#
# These are used **only** to:
#
# * Fetch your official Kaggle score
# * Export your top WandB runs for grading
#
# ⚠️ Do **not** share your API keys publicly.

# %%
# @title
KAGGLE_USERNAME = "andersonawolossou" # TODO
KAGGLE_API_KEY  = "Kaggle_key"      # TODO
WANDB_API_KEY   = "wandb_key"  # TODO
WANDB_USERNAME_OR_TEAMNAME = "aawoloss-carnegie-mellon-university" # TODO: Put your username-or-team-name here
WANDB_PROJECT              = "IDL-HW4-P2"         # TODO: Put your project-name

# %% [markdown]
# ### Step 4: Set File Paths Correctly

# %% [markdown]
# You must provide absolute path to your **final notebook**
#
# ### Platform-specific guidance
#
# **Colab**
#
# * Right-click a file in the left file pane → **Copy path**
# * Paths typically start with `/content/...`
#
# **Kaggle**
#
# * Download your notebook (`File → Download Notebook`)
# * Upload it via **Upload Input → Upload Model**
# * Copy paths from the right sidebar (`/kaggle/working/...`)
#
# **PSC / Linux**
#
# * Locate files under `/jet/home/<your_username>/`
# * Use `!ls` to confirm paths
#
# Paste the correct path below.

# %%
NOTEBOOK_PATH = "/ocean/projects/cis260061p/awolosso/IDL/HW4/" # TODO

# %% [markdown]
# ### Step 5: (Optional) Additional Files

# %% [markdown]
# If you have extra files you want to include (e.g., config files, scripts), add their paths to `ADDITIONAL_FILES`, Otherwise, leave this list empty.

# %%
ADDITIONAL_FILES = []

# %% [markdown]
# ### Step 6: Generate the Final Submission Zip
#
# Before running the submission cell:
#
# * Ensure `ACKNOWLEDGED = True`
# * Double-check all paths and credentials
# * Confirm your Kaggle submission exists
#
# Then run the cell below.
# This should generate a `HW2P2_final_submission.zip` which includes:
# * Your notebook
# * `model_metadata_*.json`
# * README
# * WandB run exports
# * Kaggle metadata
# * Academic integrity acknowledgement

# %%
#### DO NOT MODIFY ####
# !git clone https://github.com/CMU-IDeeL/S26-HWP2-Submission-Backend.git
# !mv S26-HWP2-Submission-Backend/submission .
# !rm -rf S26-HWP2-Submission-Backend
from submission.submission_config import SubmissionConfig
from submission.backend_config import BackendConfig, HW4P2_BACKEND_CONFIG # TODO: Change to the appropriate backend config
from submission.main import create_submission_zip

create_submission_zip(
    cfg = SubmissionConfig(
        model = MODEL,
        kaggle_username  = KAGGLE_USERNAME,
        kaggle_api_key   = KAGGLE_API_KEY,
        wandb_api_key    = WANDB_API_KEY,
        wandb_entity     = WANDB_USERNAME_OR_TEAMNAME,
        wandb_project    = WANDB_PROJECT,
        acknowledged     = ACKNOWLEDGED,
        readme           = README,
        notebook_path    = NOTEBOOK_PATH,
        additional_files = ADDITIONAL_FILES
    ),
    backend_cfg = HW4P2_BACKEND_CONFIG
)

# %% [markdown]
# ### Step 7: Upload to Autolab
#
# 1. Download `HWXP2_final_submission.zip`
# 2. Upload it to **Autolab**
# 3. Verify the upload succeeds
#
# ⚠️ Submitting an incomplete zip or modifying backend code may result in grading penalties or an Academic Integrity Violation.
#
# ---
#
# ### ✅ Final Checklist
#
# Before submitting, confirm:
#
# * [ ] Kaggle username is valid
# * [ ] `model_metadata_*.json` matches your best run
# * [ ] README is complete
# * [ ] File paths are correct
# * [ ] `ACKNOWLEDGED = True`
# * [ ] Final zip downloads successfully
